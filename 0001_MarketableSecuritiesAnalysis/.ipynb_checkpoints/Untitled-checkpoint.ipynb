# %%
import os
from dotenv import load_dotenv
from datetime import date, timedelta
import requests
import zipfile
import io
import logging
from datetime import date, timedelta
import pandas as pd
import numpy as np
import yfinance as yfinance
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from edinet_xbrl.edinet_xbrl_parser import EdinetXbrlParser

load_dotenv()
EDINET_API_KEY = os.getenv('EDINET_API_KEY')

# %%
def get_documents_by_date(target_date, doc_type='030000'):
    """
    指定した日付にEDINETで開示された書類一覧を取得し、
    指定doc_type(有報)を満たすdoc_idとedinet_codeのリストを返す。
    """
    if isinstance(target_date, date):
        date_str = target_date.strftime("%Y-%m-%d")
    else:
        date_str = target_date
    base_url = "https://disclosure.edinet-fsa.go.jp/api/v2/documents.json"
    params = {'date': date_str, 'type': 2,'Subscription-Key':EDINET_API_KEY}
    r = requests.get(base_url, params=params)
    r.raise_for_status()
    data = r.json()
    results = data.get('results', [])

    docs = []


    for d in results:
        if d.get('formCode') == doc_type and d.get('docTypeCode') == '120':
            docs.append(d)

    return docs

h = get_documents_by_date(date(2024, 6, 11),doc_type='030000')

# %%
doc_id = h[0]['docID']
periodEnd_date= date.fromisoformat(h[0]['periodEnd'])

# %%
h
# Out:
# [{'seqNumber': 132,
#   'docID': 'S100TKQK',
#   'edinetCode': 'E03575',
#   'secCode': '83660',
#   'JCN': '6160001000993',
#   'filerName': '株式会社滋賀銀行',
#   'fundCode': None,
#   'ordinanceCode': '010',
#   'formCode': '030000',
#   'docTypeCode': '120',
#   'periodStart': '2023-04-01',
#   'periodEnd': '2024-03-31',
#   'submitDateTime': '2024-06-11 10:05',
#   'docDescription': '有価証券報告書－第137期(2023/04/01－2024/03/31)',
#   'issuerEdinetCode': None,
#   'subjectEdinetCode': None,
#   'subsidiaryEdinetCode': None,
#   'currentReportReason': None,
#   'parentDocID': None,
#   'opeDateTime': None,
#   'withdrawalStatus': '0',
#   'docInfoEditStatus': '0',
#   'disclosureStatus': '0',
#   'xbrlFlag': '1',
#   'pdfFlag': '1',
#   'attachDocFlag': '1',
#   'englishDocFlag': '0',
#   'csvFlag': '1',
#   'legalStatus': '1'}]

# %%
import os
import io
import zipfile
import tempfile
import requests
import logging

def download_xbrl_file(doc_id,output_dir = "./xbrl/"):
    """

    """
    path = output_dir + doc_id + '/'
    
    base_url = "https://disclosure.edinet-fsa.go.jp/api/v2/documents"
    params = {
        'type': 1,
        'Subscription-Key': EDINET_API_KEY
    }
    
    try:
        response = requests.get(f"{base_url}/{doc_id}", params=params, stream=True)
        response.raise_for_status()
    except Exception as e:
        logging.error("EDINET APIからのダウンロードに失敗しました: %s", e)
        return None
    
    # try:
    # ダウンロードしたZIPアーカイブをメモリ上で読み込む
    
    z = zipfile.ZipFile(io.BytesIO(response.content))
    # 出力先ディレクトリの作成
    if not os.path.exists(path):
        os.makedirs(path)
            
    filename = doc_id + ".zip"
    with open(path+filename, 'wb') as f:    
        for chunk in response.iter_content(chunk_size=1024):
          f.write(chunk)

    with zipfile.ZipFile(path+filename) as zip_f:
        zip_f.extractall(path)


        # ZIP 内で拡張子が .xbrl のファイルを検索（大文字小文字区別しない）
        xbrl_files = [f for f in zip_f.namelist() if f.lower().endswith('.xbrl')]
        if not xbrl_files:
            logging.warning("doc_id=%s のZIP内にXBRLファイルが見つかりませんでした", doc_id)
            return None
        
        # 例として最初に見つかった XBRL ファイルの絶対パスを返す
        xbrl_file_rel_path = xbrl_files[0]
        current_directory = os.getcwd()
        xbrl_file_abs_path = os.path.join(current_directory + path[1:], xbrl_file_rel_path)
        
    return xbrl_file_abs_path

# %%
xbrl_file_abs_path = download_xbrl_file(doc_id)

# %%
import os
import pandas as pd
from arelle import Cntlr

def extract_financial_data(xbrl_file):
    # Arelle のコントローラ作成（ログ出力は標準出力に設定）
    cntlr = Cntlr.Cntlr(logFileName='logToPrint')
    
    # XBRL ファイルを読み込み
    modelXbrl = cntlr.modelManager.load(xbrl_file)
    
    # 抽出データを格納するリスト
    data = []
    
    # 各 fact から情報を抽出
    for fact in modelXbrl.facts:
        # 必要な情報例: コンセプト、値、単位、コンテキストID
        row = {
            'concept': fact.concept.qname.localName,
            'concept_jp':fact.concept.label(preferredLabel=None, lang='ja', linkroleHint=None), 
            'value': fact.value,
            'unit': fact.unitID if fact.unitID else '',
            'context': fact.contextID,

        }
        data.append(row)
    
    # リストを pandas DataFrame に変換
    df = pd.DataFrame(data)
    return df

def set_context_YYYY(context_str):
    """
    context の文字列に含まれるキーワードに基づいて、
    対象期を periodEnd から何年前か計算し、'YYYY' 形式で返す。
    """
    if "CurrentYear" in context_str:
        target_date = periodEnd_date
    elif "Prior1Year" in context_str:
        target_date = periodEnd_date.replace(year=periodEnd_date.year - 1)
    elif "Prior2Year" in context_str:
        target_date = periodEnd_date.replace(year=periodEnd_date.year - 2)
    elif "Prior3Year" in context_str:
        target_date = periodEnd_date.replace(year=periodEnd_date.year - 3)
    elif "Prior4Year" in context_str:
        target_date = periodEnd_date.replace(year=periodEnd_date.year - 4)
    else:
        # 対象外の場合は None を返す
        return None
    
    return target_date.strftime("%Y")

def set_context_NCM(context_str):
    """
    context の文字列に含まれるキーワードに基づいて、
    連結か非連結（単独）かを判断する。
    """
    if "NonConsolidatedMember" in context_str:
        return True
        
    return False


xbrl_path = xbrl_file_abs_path  # 解析対象の XBRL ファイルパスに変更
if os.path.exists(xbrl_path):
    df = extract_financial_data(xbrl_path)

else:
    print("XBRL ファイルが見つかりません:", xbrl_path)

# %%
df
# Out:
#                                                 concept     concept_jp  \
# 0                                 NumberOfSubmissionDEI           提出回数
# 1                OrdinaryIncomeSummaryOfBusinessResults           経常収益
# 2                OrdinaryIncomeSummaryOfBusinessResults           経常収益
# 3                OrdinaryIncomeSummaryOfBusinessResults           経常収益
# 4                OrdinaryIncomeSummaryOfBusinessResults           経常収益
# ...                                                 ...            ...
# 2248    OtherInformationFinancialStatementsEtcTextBlock            その他
# 2249  OverviewOfOperationalProceduresForSharesTextBlock   提出会社の株式事務の概要
# 2250  InformationAboutParentCompanyEtcOfReportingCom...   提出会社の親会社等の情報
# 2251                 OtherReferenceInformationTextBlock       その他の参考情報
# 2252  InformationAboutCompanyWhichProvidesGuaranteeT...  提出会社の保証会社等の情報
#
#                                                   value  unit  \
# 0                                                     1  pure
# 1                                           88871000000   JPY
# 2                                           85715000000   JPY
# 3                                           98306000000   JPY
# 4                                          115289000000   JPY
# ...                                                 ...   ...
# 2248  <p class="smt_head3" style="orphans:0;widows:0...
# 2249  \n<h2 class="smt_head1">第６ 【提出会社の株式事務の概要】</h2>...
# 2250  \n１ 【提出会社の親会社等の情報】当行は、法第24条の７第１項に規定する親会社等はございま...
# 2251  \n<h3 class="smt_head2" style="font-family:&ap...
# 2252  \n<h1 class="smt_head1">第二部 【提出会社の保証会社等の情報】</h...
#
#                   context context_YYYY  context_NCM
# 0       FilingDateInstant         None        False
# 1      Prior4YearDuration         2020        False
# 2      Prior3YearDuration         2021        False
# 3      Prior2YearDuration         2022        False
# 4      Prior1YearDuration         2023        False
# ...                   ...          ...          ...
# 2248  CurrentYearDuration         2024        False
# 2249    FilingDateInstant         None        False
# 2250    FilingDateInstant         None        False
# 2251    FilingDateInstant         None        False
# 2252    FilingDateInstant         None        False
#
# [2253 rows x 7 columns]

# %% [markdown]
# ### assets = df[df['unit']=='JPY']
# # assets = assets.copy()
# # assets['context_YYYY'] = assets['context'].apply(set_context_YYYY)
# # assets['context_NCM'] = assets['context'].apply(set_context_NCM)
#
# df = df.copy()
# df['context_YYYY'] = df['context'].apply(set_context_YYYY)
# df['context_NCM'] = df['context'].apply(set_context_NCM)

# %%
# Out:
# 2250    \n１ 【提出会社の親会社等の情報】当行は、法第24条の７第１項に規定する親会社等はございま...
# Name: value, dtype: object

# %%
columns_to_check = ['concept_jp']

filtered_df = df[
    df[columns_to_check]
    .apply(lambda row: row.astype(str).str.contains("配当").any(), axis=1)
]

# %%
filtered_df
# Out:
#                                                 concept  concept_jp  \
# 161        DividendPaidPerShareSummaryOfBusinessResults    １株当たり配当額
# 162        DividendPaidPerShareSummaryOfBusinessResults    １株当たり配当額
# 163        DividendPaidPerShareSummaryOfBusinessResults    １株当たり配当額
# 164        DividendPaidPerShareSummaryOfBusinessResults    １株当たり配当額
# 165        DividendPaidPerShareSummaryOfBusinessResults    １株当たり配当額
# 166   InterimDividendPaidPerShareSummaryOfBusinessRe...  １株当たり中間配当額
# 167   InterimDividendPaidPerShareSummaryOfBusinessRe...  １株当たり中間配当額
# 168   InterimDividendPaidPerShareSummaryOfBusinessRe...  １株当たり中間配当額
# 169   InterimDividendPaidPerShareSummaryOfBusinessRe...  １株当たり中間配当額
# 170   InterimDividendPaidPerShareSummaryOfBusinessRe...  １株当たり中間配当額
# 196                 PayoutRatioSummaryOfBusinessResults        配当性向
# 197                 PayoutRatioSummaryOfBusinessResults        配当性向
# 198                 PayoutRatioSummaryOfBusinessResults        配当性向
# 199                 PayoutRatioSummaryOfBusinessResults        配当性向
# 200                 PayoutRatioSummaryOfBusinessResults        配当性向
# 372            TotalAmountOfDividendsDividendsOfSurplus      配当金の総額
# 373                  DividendPerShareDividendsOfSurplus    １株当たり配当額
# 374            TotalAmountOfDividendsDividendsOfSurplus      配当金の総額
# 375                  DividendPerShareDividendsOfSurplus    １株当たり配当額
# 733   TotalOfDividendsReceivedEquitySecuritiesOtherT...   受取配当金の合計額
# 736   TotalOfDividendsReceivedEquitySecuritiesNotLis...   受取配当金の合計額
# 857               InterestAndDividendsOnSecuritiesOIBNK   有価証券利息配当金
# 858               InterestAndDividendsOnSecuritiesOIBNK   有価証券利息配当金
# 948                                DividendsFromSurplus      剰余金の配当
# 949                                DividendsFromSurplus      剰余金の配当
# 976                                DividendsFromSurplus      剰余金の配当
# 1007                               DividendsFromSurplus      剰余金の配当
# 1008                               DividendsFromSurplus      剰余金の配当
# 1034                               DividendsFromSurplus      剰余金の配当
# 1145                             CashDividendsPaidFinCF     配当金の支払額
# 1146                             CashDividendsPaidFinCF     配当金の支払額
# 1344              InterestAndDividendsOnSecuritiesOIBNK   有価証券利息配当金
# 1345              InterestAndDividendsOnSecuritiesOIBNK   有価証券利息配当金
# 1467                               DividendsFromSurplus      剰余金の配当
# 1468                               DividendsFromSurplus      剰余金の配当
# 1469                               DividendsFromSurplus      剰余金の配当
# 1516                               DividendsFromSurplus      剰余金の配当
# 1550                               DividendsFromSurplus      剰余金の配当
# 1551                               DividendsFromSurplus      剰余金の配当
# 1552                               DividendsFromSurplus      剰余金の配当
# 1595                               DividendsFromSurplus      剰余金の配当
# 1771                            DividendPolicyTextBlock        配当政策
# 2191                    NotesRegardingDividendTextBlock    配当に関する注記
# 2194                    NotesRegardingDividendTextBlock    配当に関する注記
#
#                                                   value          unit  \
# 161                                               40.00  JPYPerShares
# 162                                               40.00  JPYPerShares
# 163                                               80.00  JPYPerShares
# 164                                               80.00  JPYPerShares
# 165                                               90.00  JPYPerShares
# 166                                               17.50  JPYPerShares
# 167                                               17.50  JPYPerShares
# 168                                               17.50  JPYPerShares
# 169                                               40.00  JPYPerShares
# 170                                               50.00  JPYPerShares
# 196                                              0.1721          pure
# 197                                              0.1771          pure
# 198                                              0.2270          pure
# 199                                              0.2655          pure
# 200                                              0.2709          pure
# 372                                          2374000000           JPY
# 373                                               50.00  JPYPerShares
# 374                                          1877000000           JPY
# 375                                               40.00  JPYPerShares
# 733                                          2749000000           JPY
# 736                                                               JPY
# 857                                         19024000000           JPY
# 858                                         25026000000           JPY
# 948                                         -4951000000           JPY
# 949                                         -4951000000           JPY
# 976                                         -4951000000           JPY
# 1007                                        -4273000000           JPY
# 1008                                        -4273000000           JPY
# 1034                                        -4273000000           JPY
# 1145                                        -4951000000           JPY
# 1146                                        -4273000000           JPY
# 1344                                        19994000000           JPY
# 1345                                        25998000000           JPY
# 1467                                        -4951000000           JPY
# 1468                                        -4951000000           JPY
# 1469                                        -4951000000           JPY
# 1516                                        -4951000000           JPY
# 1550                                        -4273000000           JPY
# 1551                                        -4273000000           JPY
# 1552                                        -4273000000           JPY
# 1595                                        -4273000000           JPY
# 1771  <p style="page-break-before:always; line-heigh...
# 2191  <p class="smt_text6" style="orphans:0;widows:0...
# 2194  <p class="smt_text6" style="orphans:0;widows:0...
#
#                                                 context context_YYYY  \
# 161            Prior4YearDuration_NonConsolidatedMember         2020
# 162            Prior3YearDuration_NonConsolidatedMember         2021
# 163            Prior2YearDuration_NonConsolidatedMember         2022
# 164            Prior1YearDuration_NonConsolidatedMember         2023
# 165           CurrentYearDuration_NonConsolidatedMember         2024
# 166            Prior4YearDuration_NonConsolidatedMember         2020
# 167            Prior3YearDuration_NonConsolidatedMember         2021
# 168            Prior2YearDuration_NonConsolidatedMember         2022
# 169            Prior1YearDuration_NonConsolidatedMember         2023
# 170           CurrentYearDuration_NonConsolidatedMember         2024
# 196            Prior4YearDuration_NonConsolidatedMember         2020
# 197            Prior3YearDuration_NonConsolidatedMember         2021
# 198            Prior2YearDuration_NonConsolidatedMember         2022
# 199            Prior1YearDuration_NonConsolidatedMember         2023
# 200           CurrentYearDuration_NonConsolidatedMember         2024
# 372                        FilingDateInstant_Row1Member         None
# 373                        FilingDateInstant_Row1Member         None
# 374                        FilingDateInstant_Row2Member         None
# 375                        FilingDateInstant_Row2Member         None
# 733                                 CurrentYearDuration         2024
# 736                                 CurrentYearDuration         2024
# 857                                  Prior1YearDuration         2023
# 858                                 CurrentYearDuration         2024
# 948           Prior1YearDuration_RetainedEarningsMember         2023
# 949         Prior1YearDuration_ShareholdersEquityMember         2023
# 976                                  Prior1YearDuration         2023
# 1007         CurrentYearDuration_RetainedEarningsMember         2024
# 1008       CurrentYearDuration_ShareholdersEquityMember         2024
# 1034                                CurrentYearDuration         2024
# 1145                                 Prior1YearDuration         2023
# 1146                                CurrentYearDuration         2024
# 1344           Prior1YearDuration_NonConsolidatedMember         2023
# 1345          CurrentYearDuration_NonConsolidatedMember         2024
# 1467  Prior1YearDuration_NonConsolidatedMember_Retai...         2023
# 1468  Prior1YearDuration_NonConsolidatedMember_Retai...         2023
# 1469  Prior1YearDuration_NonConsolidatedMember_Share...         2023
# 1516           Prior1YearDuration_NonConsolidatedMember         2023
# 1550  CurrentYearDuration_NonConsolidatedMember_Reta...         2024
# 1551  CurrentYearDuration_NonConsolidatedMember_Reta...         2024
# 1552  CurrentYearDuration_NonConsolidatedMember_Shar...         2024
# 1595          CurrentYearDuration_NonConsolidatedMember         2024
# 1771                                  FilingDateInstant         None
# 2191                                 Prior1YearDuration         2023
# 2194                                CurrentYearDuration         2024
#
#       context_NCM
# 161          True
# 162          True
# 163          True
# 164          True
# 165          True
# 166          True
# 167          True
# 168          True
# 169          True
# 170          True
# 196          True
# 197          True
# 198          True
# 199          True
# 200          True
# 372         False
# 373         False
# 374         False
# 375         False
# 733         False
# 736         False
# 857         False
# 858         False
# 948         False
# 949         False
# 976         False
# 1007        False
# 1008        False
# 1034        False
# 1145        False
# 1146        False
# 1344         True
# 1345         True
# 1467         True
# 1468         True
# 1469         True
# 1516         True
# 1550         True
# 1551         True
# 1552         True
# 1595         True
# 1771        False
# 2191        False
# 2194        False

# %%
from dotenv import load_dotenv
import os
from sshtunnel import SSHTunnelForwarder
from pymongo import MongoClient


# .envファイルをロードして環境変数を読み込む
load_dotenv()

# SSH接続情報（.envから読み込み）
SSH_HOST = os.getenv('SSH_HOST')
SSH_PORT = int(os.getenv('SSH_PORT', 22))
SSH_USERNAME = os.getenv('SSH_USERNAME')
SSH_PASSWORD = os.getenv('SSH_PASSWORD')

# MongoDB接続情報（.envから読み込み）
MONGO_HOST = os.getenv('MONGO_HOST', '127.0.0.1')
MONGO_PORT = int(os.getenv('MONGO_PORT', 27017))
DATABASE_NAME = 'test'
COLLECTION_NAME = 'collection'
    
def ssh_connection_and_write(df):
    tunnel = SSHTunnelForwarder(
        (SSH_HOST, SSH_PORT),
        ssh_username=SSH_USERNAME,
        ssh_password=SSH_PASSWORD,
        remote_bind_address=(MONGO_HOST, MONGO_PORT)
    )
    tunnel.start()
    try:
        local_port = tunnel.local_bind_port
        print(f"SSHトンネル確立: ローカルポート {local_port} がリモートの {MONGO_HOST}:{MONGO_PORT} にマッピングされました。")
        
        client = MongoClient('127.0.0.1', local_port)
        db = client[DATABASE_NAME]
        collection = db[COLLECTION_NAME]
        
        records = df.to_dict(orient='records')
        result = collection.insert_many(records

    finally:
        tunnel.stop()
        
    return result.inserted_ids

collection = ssh_conection()
write_dataframe_to_mongo(collection,df)
# Out:
# 2025-02-21 11:27:49,906| ERROR   | Could not establish connection from local ('127.0.0.1', 56376) to remote ('127.0.0.1', 27017) side of the tunnel: open new channel ssh error: SSH session not active
# SSHトンネル確立: ローカルポート 56376 がリモートの 127.0.0.1:27017 にマッピングされました。
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[69], line 42
#      39     return result.inserted_ids
#      41 collection = ssh_conection()
# ---> 42 write_dataframe_to_mongo(collection,df)
#
# Cell In[66], line 37, in write_dataframe_to_mongo(collection, df)
#      34 records = df.to_dict(orient='records')
#      36 # insert_manyを使用して一括挿入
# ---> 37 result = collection.insert_many(records)
#      38 return result.inserted_ids
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/synchronous/collection.py:975, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974 blk.ops = list(gen())
# --> 975 blk.execute(write_concern, session, _Op.INSERT)
#     976 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/synchronous/bulk.py:751, in _Bulk.execute(self, write_concern, session, operation)
#     749         return None
#     750 else:
# --> 751     return self.execute_command(generator, write_concern, session, operation)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/synchronous/bulk.py:604, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     593     self._execute_command(
#     594         generator,
#     595         write_concern,
#    (...)
#     600         full_result,
#     601     )
#     603 client = self.collection.database.client
# --> 604 _ = client._retryable_write(
#     605     self.is_retryable,
#     606     retryable_bulk,
#     607     session,
#     608     operation,
#     609     bulk=self,  # type: ignore[arg-type]
#     610     operation_id=op_id,
#     611 )
#     613 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     614     _raise_bulk_write_error(full_result)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:1896, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    1882 """Execute an operation with consecutive retries if possible
#    1883
#    1884 Returns func()'s return value on success. On error retries the same
#    (...)
#    1893 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    1894 """
#    1895 with self._tmp_session(session) as s:
# -> 1896     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:1782, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1777 # Ensure that the options supports retry_writes and there is a valid session not in
#    1778 # transaction, otherwise, we will not support retry behavior for this txn.
#    1779 retryable = bool(
#    1780     retryable and self.options.retry_writes and session and not session.in_transaction
#    1781 )
# -> 1782 return self._retry_internal(
#    1783     func=func,
#    1784     session=session,
#    1785     bulk=bulk,
#    1786     operation=operation,
#    1787     retryable=retryable,
#    1788     operation_id=operation_id,
#    1789 )
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:1828, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1791 @_csot.apply
#    1792 def _retry_internal(
#    1793     self,
#    (...)
#    1802     operation_id: Optional[int] = None,
#    1803 ) -> T:
#    1804     """Internal retryable helper for all client transactions.
#    1805
#    1806     :param func: Callback function we want to retry
#    (...)
#    1815     :return: Output of the calling func()
#    1816     """
#    1817     return _ClientConnectionRetryable(
#    1818         mongo_client=self,
#    1819         func=func,
#    1820         bulk=bulk,
#    1821         operation=operation,
#    1822         is_read=is_read,
#    1823         session=session,
#    1824         read_pref=read_pref,
#    1825         address=address,
#    1826         retryable=retryable,
#    1827         operation_id=operation_id,
# -> 1828     ).run()
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2565, in _ClientConnectionRetryable.run(self)
#    2563 self._check_last_error(check_csot=True)
#    2564 try:
# -> 2565     return self._read() if self._is_read else self._write()
#    2566 except ServerSelectionTimeoutError:
#    2567     # The application may think the write was never attempted
#    2568     # if we raise ServerSelectionTimeoutError on the retry
#    2569     # attempt. Raise the original exception instead.
#    2570     self._check_last_error()
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2673, in _ClientConnectionRetryable._write(self)
#    2671 max_wire_version = 0
#    2672 is_mongos = False
# -> 2673 self._server = self._get_server()
#    2674 with self._client._checkout(self._server, self._session) as conn:
#    2675     max_wire_version = conn.max_wire_version
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2656, in _ClientConnectionRetryable._get_server(self)
#    2651 def _get_server(self) -> Server:
#    2652     """Retrieves a server object based on provided object context
#    2653
#    2654     :return: Abstraction to connect to server
#    2655     """
# -> 2656     return self._client._select_server(
#    2657         self._server_selector,
#    2658         self._session,
#    2659         self._operation,
#    2660         address=self._address,
#    2661         deprioritized_servers=self._deprioritized_servers,
#    2662         operation_id=self._operation_id,
#    2663     )
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:1647, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1645             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1646     else:
# -> 1647         server = topology.select_server(
#    1648             server_selector,
#    1649             operation,
#    1650             deprioritized_servers=deprioritized_servers,
#    1651             operation_id=operation_id,
#    1652         )
#    1653     return server
#    1654 except PyMongoError as exc:
#    1655     # Server selection errors in a transaction are transient.
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/synchronous/topology.py:402, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     392 def select_server(
#     393     self,
#     394     selector: Callable[[Selection], Selection],
#    (...)
#     399     operation_id: Optional[int] = None,
#     400 ) -> Server:
#     401     """Like select_servers, but choose a random server if several match."""
# --> 402     server = self._select_server(
#     403         selector,
#     404         operation,
#     405         server_selection_timeout,
#     406         address,
#     407         deprioritized_servers,
#     408         operation_id=operation_id,
#     409     )
#     410     if _csot.get_timeout():
#     411         _csot.set_rtt(server.description.min_round_trip_time)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/synchronous/topology.py:380, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     371 def _select_server(
#     372     self,
#     373     selector: Callable[[Selection], Selection],
#    (...)
#     378     operation_id: Optional[int] = None,
#     379 ) -> Server:
# --> 380     servers = self.select_servers(
#     381         selector, operation, server_selection_timeout, address, operation_id
#     382     )
#     383     servers = _filter_servers(servers, deprioritized_servers)
#     384     if len(servers) == 1:
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/synchronous/topology.py:287, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id)
#     284     server_timeout = server_selection_timeout
#     286 with self._lock:
# --> 287     server_descriptions = self._select_servers_loop(
#     288         selector, server_timeout, operation, operation_id, address
#     289     )
#     291     return [
#     292         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     293     ]
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/synchronous/topology.py:337, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address)
#     326     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     327         _debug_log(
#     328             _SERVER_SELECTION_LOGGER,
#     329             message=_ServerSelectionStatusMessage.FAILED,
#    (...)
#     335             failure=self._error_message(selector),
#     336         )
# --> 337     raise ServerSelectionTimeoutError(
#     338         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     339     )
#     341 if not logged_waiting:
#     342     _debug_log(
#     343         _SERVER_SELECTION_LOGGER,
#     344         message=_ServerSelectionStatusMessage.WAITING,
#    (...)
#     350         remainingTimeMS=int(end_time - time.monotonic()),
#     351     )
#
# ServerSelectionTimeoutError: 127.0.0.1:56376: [Errno 61] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 67b7e4a58d297929dd949476, topology_type: Unknown, servers: [<ServerDescription ('127.0.0.1', 56376) server_type: Unknown, rtt: None, error=AutoReconnect('127.0.0.1:56376: [Errno 61] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
records = df.to_dict(orient='records')
records
# Out:
# [{'concept': 'NumberOfSubmissionDEI',
#   'concept_jp': '提出回数',
#   'value': '1',
#   'unit': 'pure',
#   'context': 'FilingDateInstant',
#   'context_YYYY': None,
#   'context_NCM': False},
#  {'concept': 'OrdinaryIncomeSummaryOfBusinessResults',
#   'concept_jp': '経常収益',
#   'value': '88871000000',
#   'unit': 'JPY',
#   'context': 'Prior4YearDuration',
#   'context_YYYY': '2020',
#   'context_NCM': False},
#  {'concept': 'OrdinaryIncomeSummaryOfBusinessResults',
#   'concept_jp': '経常収益',
#   'value': '85715000000',
#   'unit': 'JPY',
#   'context': 'Prior3YearDuration',
#   'context_YYYY': '2021',
#   'context_NCM': False},
#  {'concept': 'OrdinaryIncomeSummaryOfBusinessResults',
#   'concept_jp': '経常収益',
#   'value': '98306000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearDuration',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'OrdinaryIncomeSummaryOfBusinessResults',
#   'concept_jp': '経常収益',
#   'value': '115289000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'OrdinaryIncomeSummaryOfBusinessResults',
#   'concept_jp': '経常収益',
#   'value': '122630000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearDuration',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'TrustFeesSummaryOfBusinessResults',
#   'concept_jp': '信託報酬',
#   'value': '',
#   'unit': 'JPY',
#   'context': 'Prior4YearDuration',
#   'context_YYYY': '2020',
#   'context_NCM': False},
#  {'concept': 'TrustFeesSummaryOfBusinessResults',
#   'concept_jp': '信託報酬',
#   'value': '2000000',
#   'unit': 'JPY',
#   'context': 'Prior3YearDuration',
#   'context_YYYY': '2021',
#   'context_NCM': False},
#  {'concept': 'TrustFeesSummaryOfBusinessResults',
#   'concept_jp': '信託報酬',
#   'value': '0',
#   'unit': 'JPY',
#   'context': 'Prior2YearDuration',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'TrustFeesSummaryOfBusinessResults',
#   'concept_jp': '信託報酬',
#   'value': '0',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'TrustFeesSummaryOfBusinessResults',
#   'concept_jp': '信託報酬',
#   'value': '0',
#   'unit': 'JPY',
#   'context': 'CurrentYearDuration',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'OrdinaryIncomeLossSummaryOfBusinessResults',
#   'concept_jp': '経常利益又は経常損失（△）',
#   'value': '13875000000',
#   'unit': 'JPY',
#   'context': 'Prior4YearDuration',
#   'context_YYYY': '2020',
#   'context_NCM': False},
#  {'concept': 'OrdinaryIncomeLossSummaryOfBusinessResults',
#   'concept_jp': '経常利益又は経常損失（△）',
#   'value': '11070000000',
#   'unit': 'JPY',
#   'context': 'Prior3YearDuration',
#   'context_YYYY': '2021',
#   'context_NCM': False},
#  {'concept': 'OrdinaryIncomeLossSummaryOfBusinessResults',
#   'concept_jp': '経常利益又は経常損失（△）',
#   'value': '23999000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearDuration',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'OrdinaryIncomeLossSummaryOfBusinessResults',
#   'concept_jp': '経常利益又は経常損失（△）',
#   'value': '20041000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'OrdinaryIncomeLossSummaryOfBusinessResults',
#   'concept_jp': '経常利益又は経常損失（△）',
#   'value': '23967000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearDuration',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'ProfitLossAttributableToOwnersOfParentSummaryOfBusinessResults',
#   'concept_jp': '親会社株主に帰属する当期純利益又は親会社株主に帰属する当期純損失（△）',
#   'value': '12412000000',
#   'unit': 'JPY',
#   'context': 'Prior4YearDuration',
#   'context_YYYY': '2020',
#   'context_NCM': False},
#  {'concept': 'ProfitLossAttributableToOwnersOfParentSummaryOfBusinessResults',
#   'concept_jp': '親会社株主に帰属する当期純利益又は親会社株主に帰属する当期純損失（△）',
#   'value': '11448000000',
#   'unit': 'JPY',
#   'context': 'Prior3YearDuration',
#   'context_YYYY': '2021',
#   'context_NCM': False},
#  {'concept': 'ProfitLossAttributableToOwnersOfParentSummaryOfBusinessResults',
#   'concept_jp': '親会社株主に帰属する当期純利益又は親会社株主に帰属する当期純損失（△）',
#   'value': '17715000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearDuration',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'ProfitLossAttributableToOwnersOfParentSummaryOfBusinessResults',
#   'concept_jp': '親会社株主に帰属する当期純利益又は親会社株主に帰属する当期純損失（△）',
#   'value': '14858000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'ProfitLossAttributableToOwnersOfParentSummaryOfBusinessResults',
#   'concept_jp': '親会社株主に帰属する当期純利益又は親会社株主に帰属する当期純損失（△）',
#   'value': '15940000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearDuration',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'ComprehensiveIncomeSummaryOfBusinessResults',
#   'concept_jp': '包括利益',
#   'value': '-22117000000',
#   'unit': 'JPY',
#   'context': 'Prior4YearDuration',
#   'context_YYYY': '2020',
#   'context_NCM': False},
#  {'concept': 'ComprehensiveIncomeSummaryOfBusinessResults',
#   'concept_jp': '包括利益',
#   'value': '122660000000',
#   'unit': 'JPY',
#   'context': 'Prior3YearDuration',
#   'context_YYYY': '2021',
#   'context_NCM': False},
#  {'concept': 'ComprehensiveIncomeSummaryOfBusinessResults',
#   'concept_jp': '包括利益',
#   'value': '-26692000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearDuration',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'ComprehensiveIncomeSummaryOfBusinessResults',
#   'concept_jp': '包括利益',
#   'value': '-15071000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'ComprehensiveIncomeSummaryOfBusinessResults',
#   'concept_jp': '包括利益',
#   'value': '55925000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearDuration',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'NetAssetsSummaryOfBusinessResults',
#   'concept_jp': '純資産額',
#   'value': '375801000000',
#   'unit': 'JPY',
#   'context': 'Prior4YearInstant',
#   'context_YYYY': '2020',
#   'context_NCM': False},
#  {'concept': 'NetAssetsSummaryOfBusinessResults',
#   'concept_jp': '純資産額',
#   'value': '495469000000',
#   'unit': 'JPY',
#   'context': 'Prior3YearInstant',
#   'context_YYYY': '2021',
#   'context_NCM': False},
#  {'concept': 'NetAssetsSummaryOfBusinessResults',
#   'concept_jp': '純資産額',
#   'value': '464214000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearInstant',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'NetAssetsSummaryOfBusinessResults',
#   'concept_jp': '純資産額',
#   'value': '441222000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearInstant',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetAssetsSummaryOfBusinessResults',
#   'concept_jp': '純資産額',
#   'value': '490887000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearInstant',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'TotalAssetsSummaryOfBusinessResults',
#   'concept_jp': '総資産額',
#   'value': '6285002000000',
#   'unit': 'JPY',
#   'context': 'Prior4YearInstant',
#   'context_YYYY': '2020',
#   'context_NCM': False},
#  {'concept': 'TotalAssetsSummaryOfBusinessResults',
#   'concept_jp': '総資産額',
#   'value': '7793748000000',
#   'unit': 'JPY',
#   'context': 'Prior3YearInstant',
#   'context_YYYY': '2021',
#   'context_NCM': False},
#  {'concept': 'TotalAssetsSummaryOfBusinessResults',
#   'concept_jp': '総資産額',
#   'value': '7537956000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearInstant',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'TotalAssetsSummaryOfBusinessResults',
#   'concept_jp': '総資産額',
#   'value': '7305698000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearInstant',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'TotalAssetsSummaryOfBusinessResults',
#   'concept_jp': '総資産額',
#   'value': '7970551000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearInstant',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'NetAssetsPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり純資産額',
#   'value': '7482.34',
#   'unit': 'JPYPerShares',
#   'context': 'Prior4YearInstant',
#   'context_YYYY': '2020',
#   'context_NCM': False},
#  {'concept': 'NetAssetsPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり純資産額',
#   'value': '9958.46',
#   'unit': 'JPYPerShares',
#   'context': 'Prior3YearInstant',
#   'context_YYYY': '2021',
#   'context_NCM': False},
#  {'concept': 'NetAssetsPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり純資産額',
#   'value': '9552.14',
#   'unit': 'JPYPerShares',
#   'context': 'Prior2YearInstant',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'NetAssetsPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり純資産額',
#   'value': '9293.39',
#   'unit': 'JPYPerShares',
#   'context': 'Prior1YearInstant',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetAssetsPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり純資産額',
#   'value': '10459.88',
#   'unit': 'JPYPerShares',
#   'context': 'CurrentYearInstant',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'BasicEarningsLossPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり当期純利益又は当期純損失（△）',
#   'value': '243.05',
#   'unit': 'JPYPerShares',
#   'context': 'Prior4YearDuration',
#   'context_YYYY': '2020',
#   'context_NCM': False},
#  {'concept': 'BasicEarningsLossPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり当期純利益又は当期純損失（△）',
#   'value': '228.12',
#   'unit': 'JPYPerShares',
#   'context': 'Prior3YearDuration',
#   'context_YYYY': '2021',
#   'context_NCM': False},
#  {'concept': 'BasicEarningsLossPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり当期純利益又は当期純損失（△）',
#   'value': '359.50',
#   'unit': 'JPYPerShares',
#   'context': 'Prior2YearDuration',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'BasicEarningsLossPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり当期純利益又は当期純損失（△）',
#   'value': '310.57',
#   'unit': 'JPYPerShares',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'BasicEarningsLossPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり当期純利益又は当期純損失（△）',
#   'value': '336.31',
#   'unit': 'JPYPerShares',
#   'context': 'CurrentYearDuration',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'DilutedEarningsPerShareSummaryOfBusinessResults',
#   'concept_jp': '潜在株式調整後１株当たり当期純利益',
#   'value': '214.19',
#   'unit': 'JPYPerShares',
#   'context': 'Prior4YearDuration',
#   'context_YYYY': '2020',
#   'context_NCM': False},
#  {'concept': 'DilutedEarningsPerShareSummaryOfBusinessResults',
#   'concept_jp': '潜在株式調整後１株当たり当期純利益',
#   'value': '220.43',
#   'unit': 'JPYPerShares',
#   'context': 'Prior3YearDuration',
#   'context_YYYY': '2021',
#   'context_NCM': False},
#  {'concept': 'DilutedEarningsPerShareSummaryOfBusinessResults',
#   'concept_jp': '潜在株式調整後１株当たり当期純利益',
#   'value': '359.20',
#   'unit': 'JPYPerShares',
#   'context': 'Prior2YearDuration',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'DilutedEarningsPerShareSummaryOfBusinessResults',
#   'concept_jp': '潜在株式調整後１株当たり当期純利益',
#   'value': '310.49',
#   'unit': 'JPYPerShares',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'DilutedEarningsPerShareSummaryOfBusinessResults',
#   'concept_jp': '潜在株式調整後１株当たり当期純利益',
#   'value': '',
#   'unit': 'JPYPerShares',
#   'context': 'CurrentYearDuration',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'EquityToAssetRatioSummaryOfBusinessResults',
#   'concept_jp': '自己資本比率',
#   'value': '0.0597',
#   'unit': 'pure',
#   'context': 'Prior4YearInstant',
#   'context_YYYY': '2020',
#   'context_NCM': False},
#  {'concept': 'EquityToAssetRatioSummaryOfBusinessResults',
#   'concept_jp': '自己資本比率',
#   'value': '0.0635',
#   'unit': 'pure',
#   'context': 'Prior3YearInstant',
#   'context_YYYY': '2021',
#   'context_NCM': False},
#  {'concept': 'EquityToAssetRatioSummaryOfBusinessResults',
#   'concept_jp': '自己資本比率',
#   'value': '0.0615',
#   'unit': 'pure',
#   'context': 'Prior2YearInstant',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'EquityToAssetRatioSummaryOfBusinessResults',
#   'concept_jp': '自己資本比率',
#   'value': '0.0603',
#   'unit': 'pure',
#   'context': 'Prior1YearInstant',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'EquityToAssetRatioSummaryOfBusinessResults',
#   'concept_jp': '自己資本比率',
#   'value': '0.0615',
#   'unit': 'pure',
#   'context': 'CurrentYearInstant',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'RateOfReturnOnEquitySummaryOfBusinessResults',
#   'concept_jp': '自己資本利益率',
#   'value': '0.0319',
#   'unit': 'pure',
#   'context': 'Prior4YearDuration',
#   'context_YYYY': '2020',
#   'context_NCM': False},
#  {'concept': 'RateOfReturnOnEquitySummaryOfBusinessResults',
#   'concept_jp': '自己資本利益率',
#   'value': '0.0262',
#   'unit': 'pure',
#   'context': 'Prior3YearDuration',
#   'context_YYYY': '2021',
#   'context_NCM': False},
#  {'concept': 'RateOfReturnOnEquitySummaryOfBusinessResults',
#   'concept_jp': '自己資本利益率',
#   'value': '0.0369',
#   'unit': 'pure',
#   'context': 'Prior2YearDuration',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'RateOfReturnOnEquitySummaryOfBusinessResults',
#   'concept_jp': '自己資本利益率',
#   'value': '0.0328',
#   'unit': 'pure',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'RateOfReturnOnEquitySummaryOfBusinessResults',
#   'concept_jp': '自己資本利益率',
#   'value': '0.0342',
#   'unit': 'pure',
#   'context': 'CurrentYearDuration',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'PriceEarningsRatioSummaryOfBusinessResults',
#   'concept_jp': '株価収益率',
#   'value': '10.56',
#   'unit': 'pure',
#   'context': 'Prior4YearDuration',
#   'context_YYYY': '2020',
#   'context_NCM': False},
#  {'concept': 'PriceEarningsRatioSummaryOfBusinessResults',
#   'concept_jp': '株価収益率',
#   'value': '10.50',
#   'unit': 'pure',
#   'context': 'Prior3YearDuration',
#   'context_YYYY': '2021',
#   'context_NCM': False},
#  {'concept': 'PriceEarningsRatioSummaryOfBusinessResults',
#   'concept_jp': '株価収益率',
#   'value': '6.15',
#   'unit': 'pure',
#   'context': 'Prior2YearDuration',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'PriceEarningsRatioSummaryOfBusinessResults',
#   'concept_jp': '株価収益率',
#   'value': '8.62',
#   'unit': 'pure',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'PriceEarningsRatioSummaryOfBusinessResults',
#   'concept_jp': '株価収益率',
#   'value': '12.47',
#   'unit': 'pure',
#   'context': 'CurrentYearDuration',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'NetCashProvidedByUsedInOperatingActivitiesSummaryOfBusinessResults',
#   'concept_jp': '営業活動によるキャッシュ・フロー',
#   'value': '131260000000',
#   'unit': 'JPY',
#   'context': 'Prior4YearDuration',
#   'context_YYYY': '2020',
#   'context_NCM': False},
#  {'concept': 'NetCashProvidedByUsedInOperatingActivitiesSummaryOfBusinessResults',
#   'concept_jp': '営業活動によるキャッシュ・フロー',
#   'value': '1240417000000',
#   'unit': 'JPY',
#   'context': 'Prior3YearDuration',
#   'context_YYYY': '2021',
#   'context_NCM': False},
#  {'concept': 'NetCashProvidedByUsedInOperatingActivitiesSummaryOfBusinessResults',
#   'concept_jp': '営業活動によるキャッシュ・フロー',
#   'value': '-278958000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearDuration',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'NetCashProvidedByUsedInOperatingActivitiesSummaryOfBusinessResults',
#   'concept_jp': '営業活動によるキャッシュ・フロー',
#   'value': '-483433000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetCashProvidedByUsedInOperatingActivitiesSummaryOfBusinessResults',
#   'concept_jp': '営業活動によるキャッシュ・フロー',
#   'value': '453292000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearDuration',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'NetCashProvidedByUsedInInvestingActivitiesSummaryOfBusinessResults',
#   'concept_jp': '投資活動によるキャッシュ・フロー',
#   'value': '6726000000',
#   'unit': 'JPY',
#   'context': 'Prior4YearDuration',
#   'context_YYYY': '2020',
#   'context_NCM': False},
#  {'concept': 'NetCashProvidedByUsedInInvestingActivitiesSummaryOfBusinessResults',
#   'concept_jp': '投資活動によるキャッシュ・フロー',
#   'value': '-127874000000',
#   'unit': 'JPY',
#   'context': 'Prior3YearDuration',
#   'context_YYYY': '2021',
#   'context_NCM': False},
#  {'concept': 'NetCashProvidedByUsedInInvestingActivitiesSummaryOfBusinessResults',
#   'concept_jp': '投資活動によるキャッシュ・フロー',
#   'value': '21823000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearDuration',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'NetCashProvidedByUsedInInvestingActivitiesSummaryOfBusinessResults',
#   'concept_jp': '投資活動によるキャッシュ・フロー',
#   'value': '-57989000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetCashProvidedByUsedInInvestingActivitiesSummaryOfBusinessResults',
#   'concept_jp': '投資活動によるキャッシュ・フロー',
#   'value': '-288586000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearDuration',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'NetCashProvidedByUsedInFinancingActivitiesSummaryOfBusinessResults',
#   'concept_jp': '財務活動によるキャッシュ・フロー',
#   'value': '-14310000000',
#   'unit': 'JPY',
#   'context': 'Prior4YearDuration',
#   'context_YYYY': '2020',
#   'context_NCM': False},
#  {'concept': 'NetCashProvidedByUsedInFinancingActivitiesSummaryOfBusinessResults',
#   'concept_jp': '財務活動によるキャッシュ・フロー',
#   'value': '-34337000000',
#   'unit': 'JPY',
#   'context': 'Prior3YearDuration',
#   'context_YYYY': '2021',
#   'context_NCM': False},
#  {'concept': 'NetCashProvidedByUsedInFinancingActivitiesSummaryOfBusinessResults',
#   'concept_jp': '財務活動によるキャッシュ・フロー',
#   'value': '-4483000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearDuration',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'NetCashProvidedByUsedInFinancingActivitiesSummaryOfBusinessResults',
#   'concept_jp': '財務活動によるキャッシュ・フロー',
#   'value': '-7954000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetCashProvidedByUsedInFinancingActivitiesSummaryOfBusinessResults',
#   'concept_jp': '財務活動によるキャッシュ・フロー',
#   'value': '-6280000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearDuration',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'CashAndCashEquivalentsSummaryOfBusinessResults',
#   'concept_jp': '現金及び現金同等物の残高',
#   'value': '934088000000',
#   'unit': 'JPY',
#   'context': 'Prior4YearInstant',
#   'context_YYYY': '2020',
#   'context_NCM': False},
#  {'concept': 'CashAndCashEquivalentsSummaryOfBusinessResults',
#   'concept_jp': '現金及び現金同等物の残高',
#   'value': '2012295000000',
#   'unit': 'JPY',
#   'context': 'Prior3YearInstant',
#   'context_YYYY': '2021',
#   'context_NCM': False},
#  {'concept': 'CashAndCashEquivalentsSummaryOfBusinessResults',
#   'concept_jp': '現金及び現金同等物の残高',
#   'value': '1750676000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearInstant',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'CashAndCashEquivalentsSummaryOfBusinessResults',
#   'concept_jp': '現金及び現金同等物の残高',
#   'value': '1201299000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearInstant',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'CashAndCashEquivalentsSummaryOfBusinessResults',
#   'concept_jp': '現金及び現金同等物の残高',
#   'value': '1359724000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearInstant',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'NumberOfEmployees',
#   'concept_jp': '従業員数',
#   'value': '2282',
#   'unit': 'pure',
#   'context': 'Prior4YearInstant',
#   'context_YYYY': '2020',
#   'context_NCM': False},
#  {'concept': 'NumberOfEmployees',
#   'concept_jp': '従業員数',
#   'value': '2286',
#   'unit': 'pure',
#   'context': 'Prior3YearInstant',
#   'context_YYYY': '2021',
#   'context_NCM': False},
#  {'concept': 'NumberOfEmployees',
#   'concept_jp': '従業員数',
#   'value': '2271',
#   'unit': 'pure',
#   'context': 'Prior2YearInstant',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'NumberOfEmployees',
#   'concept_jp': '従業員数',
#   'value': '2198',
#   'unit': 'pure',
#   'context': 'Prior1YearInstant',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NumberOfEmployees',
#   'concept_jp': '従業員数',
#   'value': '2154',
#   'unit': 'pure',
#   'context': 'CurrentYearInstant',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'AverageNumberOfTemporaryWorkers',
#   'concept_jp': '平均臨時雇用人員',
#   'value': '1198',
#   'unit': 'pure',
#   'context': 'Prior4YearInstant',
#   'context_YYYY': '2020',
#   'context_NCM': False},
#  {'concept': 'AverageNumberOfTemporaryWorkers',
#   'concept_jp': '平均臨時雇用人員',
#   'value': '1153',
#   'unit': 'pure',
#   'context': 'Prior3YearInstant',
#   'context_YYYY': '2021',
#   'context_NCM': False},
#  {'concept': 'AverageNumberOfTemporaryWorkers',
#   'concept_jp': '平均臨時雇用人員',
#   'value': '1102',
#   'unit': 'pure',
#   'context': 'Prior2YearInstant',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'AverageNumberOfTemporaryWorkers',
#   'concept_jp': '平均臨時雇用人員',
#   'value': '1056',
#   'unit': 'pure',
#   'context': 'Prior1YearInstant',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'AverageNumberOfTemporaryWorkers',
#   'concept_jp': '平均臨時雇用人員',
#   'value': '1002',
#   'unit': 'pure',
#   'context': 'CurrentYearInstant',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'TrustPropertySummaryOfBusinessResults',
#   'concept_jp': '信託財産額',
#   'value': '',
#   'unit': 'JPY',
#   'context': 'Prior4YearDuration',
#   'context_YYYY': '2020',
#   'context_NCM': False},
#  {'concept': 'TrustPropertySummaryOfBusinessResults',
#   'concept_jp': '信託財産額',
#   'value': '166000000',
#   'unit': 'JPY',
#   'context': 'Prior3YearDuration',
#   'context_YYYY': '2021',
#   'context_NCM': False},
#  {'concept': 'TrustPropertySummaryOfBusinessResults',
#   'concept_jp': '信託財産額',
#   'value': '214000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearDuration',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'TrustPropertySummaryOfBusinessResults',
#   'concept_jp': '信託財産額',
#   'value': '187000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'TrustPropertySummaryOfBusinessResults',
#   'concept_jp': '信託財産額',
#   'value': '184000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearDuration',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'OrdinaryIncomeSummaryOfBusinessResults',
#   'concept_jp': '経常収益',
#   'value': '73250000000',
#   'unit': 'JPY',
#   'context': 'Prior4YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'OrdinaryIncomeSummaryOfBusinessResults',
#   'concept_jp': '経常収益',
#   'value': '72610000000',
#   'unit': 'JPY',
#   'context': 'Prior3YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2021',
#   'context_NCM': True},
#  {'concept': 'OrdinaryIncomeSummaryOfBusinessResults',
#   'concept_jp': '経常収益',
#   'value': '86664000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2022',
#   'context_NCM': True},
#  {'concept': 'OrdinaryIncomeSummaryOfBusinessResults',
#   'concept_jp': '経常収益',
#   'value': '103401000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2023',
#   'context_NCM': True},
#  {'concept': 'OrdinaryIncomeSummaryOfBusinessResults',
#   'concept_jp': '経常収益',
#   'value': '110306000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearDuration_NonConsolidatedMember',
#   'context_YYYY': '2024',
#   'context_NCM': True},
#  {'concept': 'TrustFeesSummaryOfBusinessResults',
#   'concept_jp': '信託報酬',
#   'value': '',
#   'unit': 'JPY',
#   'context': 'Prior4YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'TrustFeesSummaryOfBusinessResults',
#   'concept_jp': '信託報酬',
#   'value': '2000000',
#   'unit': 'JPY',
#   'context': 'Prior3YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2021',
#   'context_NCM': True},
#  {'concept': 'TrustFeesSummaryOfBusinessResults',
#   'concept_jp': '信託報酬',
#   'value': '0',
#   'unit': 'JPY',
#   'context': 'Prior2YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2022',
#   'context_NCM': True},
#  {'concept': 'TrustFeesSummaryOfBusinessResults',
#   'concept_jp': '信託報酬',
#   'value': '0',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2023',
#   'context_NCM': True},
#  {'concept': 'TrustFeesSummaryOfBusinessResults',
#   'concept_jp': '信託報酬',
#   'value': '0',
#   'unit': 'JPY',
#   'context': 'CurrentYearDuration_NonConsolidatedMember',
#   'context_YYYY': '2024',
#   'context_NCM': True},
#  {'concept': 'OrdinaryIncomeLossSummaryOfBusinessResults',
#   'concept_jp': '経常利益又は経常損失（△）',
#   'value': '12538000000',
#   'unit': 'JPY',
#   'context': 'Prior4YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'OrdinaryIncomeLossSummaryOfBusinessResults',
#   'concept_jp': '経常利益又は経常損失（△）',
#   'value': '10375000000',
#   'unit': 'JPY',
#   'context': 'Prior3YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2021',
#   'context_NCM': True},
#  {'concept': 'OrdinaryIncomeLossSummaryOfBusinessResults',
#   'concept_jp': '経常利益又は経常損失（△）',
#   'value': '22942000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2022',
#   'context_NCM': True},
#  {'concept': 'OrdinaryIncomeLossSummaryOfBusinessResults',
#   'concept_jp': '経常利益又は経常損失（△）',
#   'value': '18841000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2023',
#   'context_NCM': True},
#  {'concept': 'OrdinaryIncomeLossSummaryOfBusinessResults',
#   'concept_jp': '経常利益又は経常損失（△）',
#   'value': '23130000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearDuration_NonConsolidatedMember',
#   'context_YYYY': '2024',
#   'context_NCM': True},
#  {'concept': 'NetIncomeLossSummaryOfBusinessResults',
#   'concept_jp': '当期純利益又は当期純損失（△）',
#   'value': '11869000000',
#   'unit': 'JPY',
#   'context': 'Prior4YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'NetIncomeLossSummaryOfBusinessResults',
#   'concept_jp': '当期純利益又は当期純損失（△）',
#   'value': '11331000000',
#   'unit': 'JPY',
#   'context': 'Prior3YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2021',
#   'context_NCM': True},
#  {'concept': 'NetIncomeLossSummaryOfBusinessResults',
#   'concept_jp': '当期純利益又は当期純損失（△）',
#   'value': '17361000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2022',
#   'context_NCM': True},
#  {'concept': 'NetIncomeLossSummaryOfBusinessResults',
#   'concept_jp': '当期純利益又は当期純損失（△）',
#   'value': '14411000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2023',
#   'context_NCM': True},
#  {'concept': 'NetIncomeLossSummaryOfBusinessResults',
#   'concept_jp': '当期純利益又は当期純損失（△）',
#   'value': '15746000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearDuration_NonConsolidatedMember',
#   'context_YYYY': '2024',
#   'context_NCM': True},
#  {'concept': 'CapitalStockSummaryOfBusinessResults',
#   'concept_jp': '資本金',
#   'value': '33076000000',
#   'unit': 'JPY',
#   'context': 'Prior4YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'CapitalStockSummaryOfBusinessResults',
#   'concept_jp': '資本金',
#   'value': '33076000000',
#   'unit': 'JPY',
#   'context': 'Prior3YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2021',
#   'context_NCM': True},
#  {'concept': 'CapitalStockSummaryOfBusinessResults',
#   'concept_jp': '資本金',
#   'value': '33076000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2022',
#   'context_NCM': True},
#  {'concept': 'CapitalStockSummaryOfBusinessResults',
#   'concept_jp': '資本金',
#   'value': '33076000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2023',
#   'context_NCM': True},
#  {'concept': 'CapitalStockSummaryOfBusinessResults',
#   'concept_jp': '資本金',
#   'value': '33076000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearInstant_NonConsolidatedMember',
#   'context_YYYY': '2024',
#   'context_NCM': True},
#  {'concept': 'TotalNumberOfIssuedSharesSummaryOfBusinessResults',
#   'concept_jp': '発行済株式総数',
#   'value': '53090000',
#   'unit': 'shares',
#   'context': 'Prior4YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'TotalNumberOfIssuedSharesSummaryOfBusinessResults',
#   'concept_jp': '発行済株式総数',
#   'value': '53090000',
#   'unit': 'shares',
#   'context': 'Prior3YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2021',
#   'context_NCM': True},
#  {'concept': 'TotalNumberOfIssuedSharesSummaryOfBusinessResults',
#   'concept_jp': '発行済株式総数',
#   'value': '53090000',
#   'unit': 'shares',
#   'context': 'Prior2YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2022',
#   'context_NCM': True},
#  {'concept': 'TotalNumberOfIssuedSharesSummaryOfBusinessResults',
#   'concept_jp': '発行済株式総数',
#   'value': '53090000',
#   'unit': 'shares',
#   'context': 'Prior1YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2023',
#   'context_NCM': True},
#  {'concept': 'TotalNumberOfIssuedSharesSummaryOfBusinessResults',
#   'concept_jp': '発行済株式総数',
#   'value': '53090000',
#   'unit': 'shares',
#   'context': 'CurrentYearInstant_NonConsolidatedMember',
#   'context_YYYY': '2024',
#   'context_NCM': True},
#  {'concept': 'NetAssetsSummaryOfBusinessResults',
#   'concept_jp': '純資産額',
#   'value': '363248000000',
#   'unit': 'JPY',
#   'context': 'Prior4YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'NetAssetsSummaryOfBusinessResults',
#   'concept_jp': '純資産額',
#   'value': '474287000000',
#   'unit': 'JPY',
#   'context': 'Prior3YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2021',
#   'context_NCM': True},
#  {'concept': 'NetAssetsSummaryOfBusinessResults',
#   'concept_jp': '純資産額',
#   'value': '445455000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2022',
#   'context_NCM': True},
#  {'concept': 'NetAssetsSummaryOfBusinessResults',
#   'concept_jp': '純資産額',
#   'value': '420344000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2023',
#   'context_NCM': True},
#  {'concept': 'NetAssetsSummaryOfBusinessResults',
#   'concept_jp': '純資産額',
#   'value': '468297000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearInstant_NonConsolidatedMember',
#   'context_YYYY': '2024',
#   'context_NCM': True},
#  {'concept': 'TotalAssetsSummaryOfBusinessResults',
#   'concept_jp': '総資産額',
#   'value': '6271836000000',
#   'unit': 'JPY',
#   'context': 'Prior4YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'TotalAssetsSummaryOfBusinessResults',
#   'concept_jp': '総資産額',
#   'value': '7769496000000',
#   'unit': 'JPY',
#   'context': 'Prior3YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2021',
#   'context_NCM': True},
#  {'concept': 'TotalAssetsSummaryOfBusinessResults',
#   'concept_jp': '総資産額',
#   'value': '7517734000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2022',
#   'context_NCM': True},
#  {'concept': 'TotalAssetsSummaryOfBusinessResults',
#   'concept_jp': '総資産額',
#   'value': '7281966000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2023',
#   'context_NCM': True},
#  {'concept': 'TotalAssetsSummaryOfBusinessResults',
#   'concept_jp': '総資産額',
#   'value': '7944199000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearInstant_NonConsolidatedMember',
#   'context_YYYY': '2024',
#   'context_NCM': True},
#  {'concept': 'DepositsSummaryOfBusinessResults',
#   'concept_jp': '預金残高',
#   'value': '4891113000000',
#   'unit': 'JPY',
#   'context': 'Prior4YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'DepositsSummaryOfBusinessResults',
#   'concept_jp': '預金残高',
#   'value': '5403957000000',
#   'unit': 'JPY',
#   'context': 'Prior3YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2021',
#   'context_NCM': True},
#  {'concept': 'DepositsSummaryOfBusinessResults',
#   'concept_jp': '預金残高',
#   'value': '5616699000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2022',
#   'context_NCM': True},
#  {'concept': 'DepositsSummaryOfBusinessResults',
#   'concept_jp': '預金残高',
#   'value': '5718288000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2023',
#   'context_NCM': True},
#  {'concept': 'DepositsSummaryOfBusinessResults',
#   'concept_jp': '預金残高',
#   'value': '5808311000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearInstant_NonConsolidatedMember',
#   'context_YYYY': '2024',
#   'context_NCM': True},
#  {'concept': 'LoansAndBillsDiscountedSummaryOfBusinessResults',
#   'concept_jp': '貸出金残高',
#   'value': '3878885000000',
#   'unit': 'JPY',
#   'context': 'Prior4YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'LoansAndBillsDiscountedSummaryOfBusinessResults',
#   'concept_jp': '貸出金残高',
#   'value': '4020228000000',
#   'unit': 'JPY',
#   'context': 'Prior3YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2021',
#   'context_NCM': True},
#  {'concept': 'LoansAndBillsDiscountedSummaryOfBusinessResults',
#   'concept_jp': '貸出金残高',
#   'value': '4082731000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2022',
#   'context_NCM': True},
#  {'concept': 'LoansAndBillsDiscountedSummaryOfBusinessResults',
#   'concept_jp': '貸出金残高',
#   'value': '4360257000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2023',
#   'context_NCM': True},
#  {'concept': 'LoansAndBillsDiscountedSummaryOfBusinessResults',
#   'concept_jp': '貸出金残高',
#   'value': '4495122000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearInstant_NonConsolidatedMember',
#   'context_YYYY': '2024',
#   'context_NCM': True},
#  {'concept': 'SecuritiesSummaryOfBusinessResults',
#   'concept_jp': '有価証券残高',
#   'value': '1310342000000',
#   'unit': 'JPY',
#   'context': 'Prior4YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'SecuritiesSummaryOfBusinessResults',
#   'concept_jp': '有価証券残高',
#   'value': '1589519000000',
#   'unit': 'JPY',
#   'context': 'Prior3YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2021',
#   'context_NCM': True},
#  {'concept': 'SecuritiesSummaryOfBusinessResults',
#   'concept_jp': '有価証券残高',
#   'value': '1515143000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2022',
#   'context_NCM': True},
#  {'concept': 'SecuritiesSummaryOfBusinessResults',
#   'concept_jp': '有価証券残高',
#   'value': '1518879000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2023',
#   'context_NCM': True},
#  {'concept': 'SecuritiesSummaryOfBusinessResults',
#   'concept_jp': '有価証券残高',
#   'value': '1860529000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearInstant_NonConsolidatedMember',
#   'context_YYYY': '2024',
#   'context_NCM': True},
#  {'concept': 'NetAssetsPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり純資産額',
#   'value': '7232.32',
#   'unit': 'JPYPerShares',
#   'context': 'Prior4YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'NetAssetsPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり純資産額',
#   'value': '9532.66',
#   'unit': 'JPYPerShares',
#   'context': 'Prior3YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2021',
#   'context_NCM': True},
#  {'concept': 'NetAssetsPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり純資産額',
#   'value': '9166.05',
#   'unit': 'JPYPerShares',
#   'context': 'Prior2YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2022',
#   'context_NCM': True},
#  {'concept': 'NetAssetsPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり純資産額',
#   'value': '8853.65',
#   'unit': 'JPYPerShares',
#   'context': 'Prior1YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2023',
#   'context_NCM': True},
#  {'concept': 'NetAssetsPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり純資産額',
#   'value': '9978.52',
#   'unit': 'JPYPerShares',
#   'context': 'CurrentYearInstant_NonConsolidatedMember',
#   'context_YYYY': '2024',
#   'context_NCM': True},
#  {'concept': 'DividendPaidPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり配当額',
#   'value': '40.00',
#   'unit': 'JPYPerShares',
#   'context': 'Prior4YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'DividendPaidPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり配当額',
#   'value': '40.00',
#   'unit': 'JPYPerShares',
#   'context': 'Prior3YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2021',
#   'context_NCM': True},
#  {'concept': 'DividendPaidPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり配当額',
#   'value': '80.00',
#   'unit': 'JPYPerShares',
#   'context': 'Prior2YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2022',
#   'context_NCM': True},
#  {'concept': 'DividendPaidPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり配当額',
#   'value': '80.00',
#   'unit': 'JPYPerShares',
#   'context': 'Prior1YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2023',
#   'context_NCM': True},
#  {'concept': 'DividendPaidPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり配当額',
#   'value': '90.00',
#   'unit': 'JPYPerShares',
#   'context': 'CurrentYearDuration_NonConsolidatedMember',
#   'context_YYYY': '2024',
#   'context_NCM': True},
#  {'concept': 'InterimDividendPaidPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり中間配当額',
#   'value': '17.50',
#   'unit': 'JPYPerShares',
#   'context': 'Prior4YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'InterimDividendPaidPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり中間配当額',
#   'value': '17.50',
#   'unit': 'JPYPerShares',
#   'context': 'Prior3YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2021',
#   'context_NCM': True},
#  {'concept': 'InterimDividendPaidPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり中間配当額',
#   'value': '17.50',
#   'unit': 'JPYPerShares',
#   'context': 'Prior2YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2022',
#   'context_NCM': True},
#  {'concept': 'InterimDividendPaidPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり中間配当額',
#   'value': '40.00',
#   'unit': 'JPYPerShares',
#   'context': 'Prior1YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2023',
#   'context_NCM': True},
#  {'concept': 'InterimDividendPaidPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり中間配当額',
#   'value': '50.00',
#   'unit': 'JPYPerShares',
#   'context': 'CurrentYearDuration_NonConsolidatedMember',
#   'context_YYYY': '2024',
#   'context_NCM': True},
#  {'concept': 'BasicEarningsLossPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり当期純利益又は当期純損失（△）',
#   'value': '232.42',
#   'unit': 'JPYPerShares',
#   'context': 'Prior4YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'BasicEarningsLossPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり当期純利益又は当期純損失（△）',
#   'value': '225.80',
#   'unit': 'JPYPerShares',
#   'context': 'Prior3YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2021',
#   'context_NCM': True},
#  {'concept': 'BasicEarningsLossPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり当期純利益又は当期純損失（△）',
#   'value': '352.32',
#   'unit': 'JPYPerShares',
#   'context': 'Prior2YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2022',
#   'context_NCM': True},
#  {'concept': 'BasicEarningsLossPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり当期純利益又は当期純損失（△）',
#   'value': '301.22',
#   'unit': 'JPYPerShares',
#   'context': 'Prior1YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2023',
#   'context_NCM': True},
#  {'concept': 'BasicEarningsLossPerShareSummaryOfBusinessResults',
#   'concept_jp': '１株当たり当期純利益又は当期純損失（△）',
#   'value': '332.22',
#   'unit': 'JPYPerShares',
#   'context': 'CurrentYearDuration_NonConsolidatedMember',
#   'context_YYYY': '2024',
#   'context_NCM': True},
#  {'concept': 'DilutedEarningsPerShareSummaryOfBusinessResults',
#   'concept_jp': '潜在株式調整後１株当たり当期純利益',
#   'value': '204.82',
#   'unit': 'JPYPerShares',
#   'context': 'Prior4YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'DilutedEarningsPerShareSummaryOfBusinessResults',
#   'concept_jp': '潜在株式調整後１株当たり当期純利益',
#   'value': '218.18',
#   'unit': 'JPYPerShares',
#   'context': 'Prior3YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2021',
#   'context_NCM': True},
#  {'concept': 'DilutedEarningsPerShareSummaryOfBusinessResults',
#   'concept_jp': '潜在株式調整後１株当たり当期純利益',
#   'value': '352.02',
#   'unit': 'JPYPerShares',
#   'context': 'Prior2YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2022',
#   'context_NCM': True},
#  {'concept': 'DilutedEarningsPerShareSummaryOfBusinessResults',
#   'concept_jp': '潜在株式調整後１株当たり当期純利益',
#   'value': '301.15',
#   'unit': 'JPYPerShares',
#   'context': 'Prior1YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2023',
#   'context_NCM': True},
#  {'concept': 'DilutedEarningsPerShareSummaryOfBusinessResults',
#   'concept_jp': '潜在株式調整後１株当たり当期純利益',
#   'value': '',
#   'unit': 'JPYPerShares',
#   'context': 'CurrentYearDuration_NonConsolidatedMember',
#   'context_YYYY': '2024',
#   'context_NCM': True},
#  {'concept': 'EquityToAssetRatioSummaryOfBusinessResults',
#   'concept_jp': '自己資本比率',
#   'value': '0.0578',
#   'unit': 'pure',
#   'context': 'Prior4YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'EquityToAssetRatioSummaryOfBusinessResults',
#   'concept_jp': '自己資本比率',
#   'value': '0.0610',
#   'unit': 'pure',
#   'context': 'Prior3YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2021',
#   'context_NCM': True},
#  {'concept': 'EquityToAssetRatioSummaryOfBusinessResults',
#   'concept_jp': '自己資本比率',
#   'value': '0.0592',
#   'unit': 'pure',
#   'context': 'Prior2YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2022',
#   'context_NCM': True},
#  {'concept': 'EquityToAssetRatioSummaryOfBusinessResults',
#   'concept_jp': '自己資本比率',
#   'value': '0.0577',
#   'unit': 'pure',
#   'context': 'Prior1YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2023',
#   'context_NCM': True},
#  {'concept': 'EquityToAssetRatioSummaryOfBusinessResults',
#   'concept_jp': '自己資本比率',
#   'value': '0.0589',
#   'unit': 'pure',
#   'context': 'CurrentYearInstant_NonConsolidatedMember',
#   'context_YYYY': '2024',
#   'context_NCM': True},
#  {'concept': 'RateOfReturnOnEquitySummaryOfBusinessResults',
#   'concept_jp': '自己資本利益率',
#   'value': '0.0315',
#   'unit': 'pure',
#   'context': 'Prior4YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'RateOfReturnOnEquitySummaryOfBusinessResults',
#   'concept_jp': '自己資本利益率',
#   'value': '0.0270',
#   'unit': 'pure',
#   'context': 'Prior3YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2021',
#   'context_NCM': True},
#  {'concept': 'RateOfReturnOnEquitySummaryOfBusinessResults',
#   'concept_jp': '自己資本利益率',
#   'value': '0.0377',
#   'unit': 'pure',
#   'context': 'Prior2YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2022',
#   'context_NCM': True},
#  {'concept': 'RateOfReturnOnEquitySummaryOfBusinessResults',
#   'concept_jp': '自己資本利益率',
#   'value': '0.0332',
#   'unit': 'pure',
#   'context': 'Prior1YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2023',
#   'context_NCM': True},
#  {'concept': 'RateOfReturnOnEquitySummaryOfBusinessResults',
#   'concept_jp': '自己資本利益率',
#   'value': '0.0354',
#   'unit': 'pure',
#   'context': 'CurrentYearDuration_NonConsolidatedMember',
#   'context_YYYY': '2024',
#   'context_NCM': True},
#  {'concept': 'PriceEarningsRatioSummaryOfBusinessResults',
#   'concept_jp': '株価収益率',
#   'value': '11.04',
#   'unit': 'pure',
#   'context': 'Prior4YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'PriceEarningsRatioSummaryOfBusinessResults',
#   'concept_jp': '株価収益率',
#   'value': '10.61',
#   'unit': 'pure',
#   'context': 'Prior3YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2021',
#   'context_NCM': True},
#  {'concept': 'PriceEarningsRatioSummaryOfBusinessResults',
#   'concept_jp': '株価収益率',
#   'value': '6.27',
#   'unit': 'pure',
#   'context': 'Prior2YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2022',
#   'context_NCM': True},
#  {'concept': 'PriceEarningsRatioSummaryOfBusinessResults',
#   'concept_jp': '株価収益率',
#   'value': '8.89',
#   'unit': 'pure',
#   'context': 'Prior1YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2023',
#   'context_NCM': True},
#  {'concept': 'PriceEarningsRatioSummaryOfBusinessResults',
#   'concept_jp': '株価収益率',
#   'value': '12.62',
#   'unit': 'pure',
#   'context': 'CurrentYearDuration_NonConsolidatedMember',
#   'context_YYYY': '2024',
#   'context_NCM': True},
#  {'concept': 'PayoutRatioSummaryOfBusinessResults',
#   'concept_jp': '配当性向',
#   'value': '0.1721',
#   'unit': 'pure',
#   'context': 'Prior4YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'PayoutRatioSummaryOfBusinessResults',
#   'concept_jp': '配当性向',
#   'value': '0.1771',
#   'unit': 'pure',
#   'context': 'Prior3YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2021',
#   'context_NCM': True},
#  {'concept': 'PayoutRatioSummaryOfBusinessResults',
#   'concept_jp': '配当性向',
#   'value': '0.2270',
#   'unit': 'pure',
#   'context': 'Prior2YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2022',
#   'context_NCM': True},
#  {'concept': 'PayoutRatioSummaryOfBusinessResults',
#   'concept_jp': '配当性向',
#   'value': '0.2655',
#   'unit': 'pure',
#   'context': 'Prior1YearDuration_NonConsolidatedMember',
#   'context_YYYY': '2023',
#   'context_NCM': True},
#  {'concept': 'PayoutRatioSummaryOfBusinessResults',
#   'concept_jp': '配当性向',
#   'value': '0.2709',
#   'unit': 'pure',
#   'context': 'CurrentYearDuration_NonConsolidatedMember',
#   'context_YYYY': '2024',
#   'context_NCM': True},
#  {'concept': 'NumberOfEmployees',
#   'concept_jp': '従業員数',
#   'value': '1989',
#   'unit': 'pure',
#   'context': 'Prior4YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'NumberOfEmployees',
#   'concept_jp': '従業員数',
#   'value': '1983',
#   'unit': 'pure',
#   'context': 'Prior3YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2021',
#   'context_NCM': True},
#  {'concept': 'NumberOfEmployees',
#   'concept_jp': '従業員数',
#   'value': '1965',
#   'unit': 'pure',
#   'context': 'Prior2YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2022',
#   'context_NCM': True},
#  {'concept': 'NumberOfEmployees',
#   'concept_jp': '従業員数',
#   'value': '1915',
#   'unit': 'pure',
#   'context': 'Prior1YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2023',
#   'context_NCM': True},
#  {'concept': 'NumberOfEmployees',
#   'concept_jp': '従業員数',
#   'value': '1875',
#   'unit': 'pure',
#   'context': 'CurrentYearInstant_NonConsolidatedMember',
#   'context_YYYY': '2024',
#   'context_NCM': True},
#  {'concept': 'AverageNumberOfTemporaryWorkers',
#   'concept_jp': '平均臨時雇用人員',
#   'value': '984',
#   'unit': 'pure',
#   'context': 'Prior4YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'AverageNumberOfTemporaryWorkers',
#   'concept_jp': '平均臨時雇用人員',
#   'value': '939',
#   'unit': 'pure',
#   'context': 'Prior3YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2021',
#   'context_NCM': True},
#  {'concept': 'AverageNumberOfTemporaryWorkers',
#   'concept_jp': '平均臨時雇用人員',
#   'value': '871',
#   'unit': 'pure',
#   'context': 'Prior2YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2022',
#   'context_NCM': True},
#  {'concept': 'AverageNumberOfTemporaryWorkers',
#   'concept_jp': '平均臨時雇用人員',
#   'value': '820',
#   'unit': 'pure',
#   'context': 'Prior1YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2023',
#   'context_NCM': True},
#  {'concept': 'AverageNumberOfTemporaryWorkers',
#   'concept_jp': '平均臨時雇用人員',
#   'value': '774',
#   'unit': 'pure',
#   'context': 'CurrentYearInstant_NonConsolidatedMember',
#   'context_YYYY': '2024',
#   'context_NCM': True},
#  {'concept': 'TotalShareholderReturn',
#   'concept_jp': '株主総利回り',
#   'value': '0.9886',
#   'unit': 'pure',
#   'context': 'Prior4YearInstant_NonConsolidatedMember',
#   'context_YYYY': '2020',
#   'context_NCM': True},
#  {'concept': 'TotalReturnOnSharePriceIndex',
# ...
#   'context_NCM': False},
#  {'concept': 'ProfitLossAttributableToOwnersOfParent',
#   'concept_jp': '親会社株主に帰属する当期純利益又は親会社株主に帰属する当期純損失（△）',
#   'value': '15940000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearDuration',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'ProfitLoss',
#   'concept_jp': '当期純利益又は当期純損失（△）',
#   'value': '14858000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'ProfitLoss',
#   'concept_jp': '当期純利益又は当期純損失（△）',
#   'value': '15940000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearDuration',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'ValuationDifferenceOnAvailableForSaleSecuritiesNetOfTaxOCI',
#   'concept_jp': 'その他有価証券評価差額金',
#   'value': '-41170000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'ValuationDifferenceOnAvailableForSaleSecuritiesNetOfTaxOCI',
#   'concept_jp': 'その他有価証券評価差額金',
#   'value': '24082000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearDuration',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'DeferredGainsOrLossesOnHedgesNetOfTaxOCI',
#   'concept_jp': '繰延ヘッジ損益',
#   'value': '9553000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'DeferredGainsOrLossesOnHedgesNetOfTaxOCI',
#   'concept_jp': '繰延ヘッジ損益',
#   'value': '14546000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearDuration',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'RemeasurementsOfDefinedBenefitPlansNetOfTaxOCI',
#   'concept_jp': '退職給付に係る調整額',
#   'value': '1687000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'RemeasurementsOfDefinedBenefitPlansNetOfTaxOCI',
#   'concept_jp': '退職給付に係る調整額',
#   'value': '1356000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearDuration',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'OtherComprehensiveIncome',
#   'concept_jp': 'その他の包括利益',
#   'value': '-29930000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'OtherComprehensiveIncome',
#   'concept_jp': 'その他の包括利益',
#   'value': '39985000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearDuration',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'ComprehensiveIncome',
#   'concept_jp': '包括利益',
#   'value': '-15071000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'ComprehensiveIncome',
#   'concept_jp': '包括利益',
#   'value': '55925000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearDuration',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'ComprehensiveIncomeAttributableToOwnersOfTheParent',
#   'concept_jp': '親会社株主に係る包括利益',
#   'value': '-15071000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'ComprehensiveIncomeAttributableToOwnersOfTheParent',
#   'concept_jp': '親会社株主に係る包括利益',
#   'value': '55925000000',
#   'unit': 'JPY',
#   'context': 'CurrentYearDuration',
#   'context_YYYY': '2024',
#   'context_NCM': False},
#  {'concept': 'NetAssets',
#   'concept_jp': '純資産',
#   'value': '33076000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearInstant_CapitalStockMember',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'NetAssets',
#   'concept_jp': '純資産',
#   'value': '24536000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearInstant_CapitalSurplusMember',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'NetAssets',
#   'concept_jp': '純資産',
#   'value': '248089000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearInstant_RetainedEarningsMember',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'NetAssets',
#   'concept_jp': '純資産',
#   'value': '-11619000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearInstant_TreasuryStockMember',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'NetAssets',
#   'concept_jp': '純資産',
#   'value': '294083000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearInstant_ShareholdersEquityMember',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'DividendsFromSurplus',
#   'concept_jp': '剰余金の配当',
#   'value': '-4951000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_RetainedEarningsMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'DividendsFromSurplus',
#   'concept_jp': '剰余金の配当',
#   'value': '-4951000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_ShareholdersEquityMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'ProfitLossAttributableToOwnersOfParent',
#   'concept_jp': '親会社株主に帰属する当期純利益又は親会社株主に帰属する当期純損失（△）',
#   'value': '14858000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_RetainedEarningsMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'ProfitLossAttributableToOwnersOfParent',
#   'concept_jp': '親会社株主に帰属する当期純利益又は親会社株主に帰属する当期純損失（△）',
#   'value': '14858000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_ShareholdersEquityMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'PurchaseOfTreasuryStock',
#   'concept_jp': '自己株式の取得',
#   'value': '-3002000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_TreasuryStockMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'PurchaseOfTreasuryStock',
#   'concept_jp': '自己株式の取得',
#   'value': '-3002000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_ShareholdersEquityMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'DisposalOfTreasuryStock',
#   'concept_jp': '自己株式の処分',
#   'value': '3000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_CapitalSurplusMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'DisposalOfTreasuryStock',
#   'concept_jp': '自己株式の処分',
#   'value': '133000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_TreasuryStockMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'DisposalOfTreasuryStock',
#   'concept_jp': '自己株式の処分',
#   'value': '137000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_ShareholdersEquityMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'ReversalOfRevaluationReserveForLand',
#   'concept_jp': '土地再評価差額金の取崩',
#   'value': '56000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_RetainedEarningsMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'ReversalOfRevaluationReserveForLand',
#   'concept_jp': '土地再評価差額金の取崩',
#   'value': '56000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_ShareholdersEquityMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'TotalChangesOfItemsDuringThePeriod',
#   'concept_jp': '当期変動額合計',
#   'value': '',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_CapitalStockMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'TotalChangesOfItemsDuringThePeriod',
#   'concept_jp': '当期変動額合計',
#   'value': '3000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_CapitalSurplusMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'TotalChangesOfItemsDuringThePeriod',
#   'concept_jp': '当期変動額合計',
#   'value': '9963000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_RetainedEarningsMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'TotalChangesOfItemsDuringThePeriod',
#   'concept_jp': '当期変動額合計',
#   'value': '-2869000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_TreasuryStockMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'TotalChangesOfItemsDuringThePeriod',
#   'concept_jp': '当期変動額合計',
#   'value': '7098000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_ShareholdersEquityMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetAssets',
#   'concept_jp': '純資産',
#   'value': '33076000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearInstant_CapitalStockMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetAssets',
#   'concept_jp': '純資産',
#   'value': '24540000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearInstant_CapitalSurplusMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetAssets',
#   'concept_jp': '純資産',
#   'value': '258053000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearInstant_RetainedEarningsMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetAssets',
#   'concept_jp': '純資産',
#   'value': '-14488000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearInstant_TreasuryStockMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetAssets',
#   'concept_jp': '純資産',
#   'value': '301181000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearInstant_ShareholdersEquityMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetAssets',
#   'concept_jp': '純資産',
#   'value': '148955000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearInstant_ValuationDifferenceOnAvailableForSaleSecuritiesMember',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'NetAssets',
#   'concept_jp': '純資産',
#   'value': '6045000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearInstant_DeferredGainsOrLossesOnHedgesMember',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'NetAssets',
#   'concept_jp': '純資産',
#   'value': '8369000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearInstant_RevaluationReserveForLandMember',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'NetAssets',
#   'concept_jp': '純資産',
#   'value': '6656000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearInstant_RemeasurementsOfDefinedBenefitPlansMember',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'NetAssets',
#   'concept_jp': '純資産',
#   'value': '170027000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearInstant_ValuationAndTranslationAdjustmentsMember',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'NetAssets',
#   'concept_jp': '純資産',
#   'value': '103000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearInstant_SubscriptionRightsToSharesMember',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'NetAssets',
#   'concept_jp': '純資産',
#   'value': '464214000000',
#   'unit': 'JPY',
#   'context': 'Prior2YearInstant',
#   'context_YYYY': '2022',
#   'context_NCM': False},
#  {'concept': 'DividendsFromSurplus',
#   'concept_jp': '剰余金の配当',
#   'value': '-4951000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'ProfitLossAttributableToOwnersOfParent',
#   'concept_jp': '親会社株主に帰属する当期純利益又は親会社株主に帰属する当期純損失（△）',
#   'value': '14858000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'PurchaseOfTreasuryStock',
#   'concept_jp': '自己株式の取得',
#   'value': '-3002000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'DisposalOfTreasuryStock',
#   'concept_jp': '自己株式の処分',
#   'value': '137000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'ReversalOfRevaluationReserveForLand',
#   'concept_jp': '土地再評価差額金の取崩',
#   'value': '56000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetChangesOfItemsOtherThanShareholdersEquity',
#   'concept_jp': '株主資本以外の項目の当期変動額（純額）',
#   'value': '-41170000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_ValuationDifferenceOnAvailableForSaleSecuritiesMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetChangesOfItemsOtherThanShareholdersEquity',
#   'concept_jp': '株主資本以外の項目の当期変動額（純額）',
#   'value': '9553000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_DeferredGainsOrLossesOnHedgesMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetChangesOfItemsOtherThanShareholdersEquity',
#   'concept_jp': '株主資本以外の項目の当期変動額（純額）',
#   'value': '-56000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_RevaluationReserveForLandMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetChangesOfItemsOtherThanShareholdersEquity',
#   'concept_jp': '株主資本以外の項目の当期変動額（純額）',
#   'value': '1687000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_RemeasurementsOfDefinedBenefitPlansMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetChangesOfItemsOtherThanShareholdersEquity',
#   'concept_jp': '株主資本以外の項目の当期変動額（純額）',
#   'value': '-29986000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_ValuationAndTranslationAdjustmentsMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetChangesOfItemsOtherThanShareholdersEquity',
#   'concept_jp': '株主資本以外の項目の当期変動額（純額）',
#   'value': '-103000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_SubscriptionRightsToSharesMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetChangesOfItemsOtherThanShareholdersEquity',
#   'concept_jp': '株主資本以外の項目の当期変動額（純額）',
#   'value': '-30090000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'TotalChangesOfItemsDuringThePeriod',
#   'concept_jp': '当期変動額合計',
#   'value': '-41170000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_ValuationDifferenceOnAvailableForSaleSecuritiesMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'TotalChangesOfItemsDuringThePeriod',
#   'concept_jp': '当期変動額合計',
#   'value': '9553000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_DeferredGainsOrLossesOnHedgesMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'TotalChangesOfItemsDuringThePeriod',
#   'concept_jp': '当期変動額合計',
#   'value': '-56000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_RevaluationReserveForLandMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'TotalChangesOfItemsDuringThePeriod',
#   'concept_jp': '当期変動額合計',
#   'value': '1687000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_RemeasurementsOfDefinedBenefitPlansMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'TotalChangesOfItemsDuringThePeriod',
#   'concept_jp': '当期変動額合計',
#   'value': '-29986000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_ValuationAndTranslationAdjustmentsMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'TotalChangesOfItemsDuringThePeriod',
#   'concept_jp': '当期変動額合計',
#   'value': '-103000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration_SubscriptionRightsToSharesMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'TotalChangesOfItemsDuringThePeriod',
#   'concept_jp': '当期変動額合計',
#   'value': '-22992000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearDuration',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetAssets',
#   'concept_jp': '純資産',
#   'value': '107785000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearInstant_ValuationDifferenceOnAvailableForSaleSecuritiesMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetAssets',
#   'concept_jp': '純資産',
#   'value': '15599000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearInstant_DeferredGainsOrLossesOnHedgesMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetAssets',
#   'concept_jp': '純資産',
#   'value': '8312000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearInstant_RevaluationReserveForLandMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetAssets',
#   'concept_jp': '純資産',
#   'value': '8343000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearInstant_RemeasurementsOfDefinedBenefitPlansMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  {'concept': 'NetAssets',
#   'concept_jp': '純資産',
#   'value': '140040000000',
#   'unit': 'JPY',
#   'context': 'Prior1YearInstant_ValuationAndTranslationAdjustmentsMember',
#   'context_YYYY': '2023',
#   'context_NCM': False},
#  ...]
